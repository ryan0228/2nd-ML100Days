# %% [markdown]
# 作業1
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#     因為工作的關係，周圍的同事沒有美術背景的同仁，自己常需要找一些Icon來點綴自己的程式，因此找圖花了蠻多時間
#     若有一個方式可以快速找到想要的圖片，我想這對自己會很有幫助
#     https://www.kaggle.com/testdotai/common-mobile-web-app-icons
#         我挑選了這個主題，來當作機器學習的第一個題目
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#     資料大部分都是透過網站收集來的，透過我不知道方法(這也是要學習的內容)搜刮而來的，每個不同的主題，整理成一個個檔案。
#
# 3. 蒐集而來的資料型態為何
#     資料收集以後，依照分類，壓縮成不同的ZIP
#
# 4. 這組資料想解決的問題如何評估
#     主要訓練這個核心，可以去找出不同的Icon，並訓練這個核心，把圖片都分類出來。

# %% [markdown]
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     首先我會先找出既有但搭乘率偏低的客戶，分析出讓他們再次搭乘的可能
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     資料來源會在已經自己之前的客戶紀錄，這些搭乘率偏低的客戶是否有某些特性，或哪那些疑慮、甚至是我們的車隊有哪些不便之處
#     資料收集部分，在客戶下車前，請他掃描的一個QRCdoe進行問卷調查，將可能發生的問題陳列，讓乘客挑選，達到資料收集
#     另外可以透過公開資訊網站，查出哪個地區的地區的大眾交通工具的搭乘率最高，這些地區也是可以招攬客源的地點
#
# 3. 蒐集而來的資料型態為何
#     資料收集若是在自己的乘客資料中，那就由資料庫中找出
#     若是資料在大眾公開資訊的話，哪麼需要能分析出標準交換格式的文件格式
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     找出歷史客戶，找出他們少搭乘的原因，並克服這些問題
#     找出大眾交通搭乘人最高的資料，在該地區增加營運據點與縮短乘客等車的時間，再驗證是否有提升業績。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    return abs(y - yp).mean()

# %%
def mean_squared_error(y,y_hat):
    return abs(np.power(y-y_hat,2)).mean()

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 228.728
# The Mean absolute error is 11.712
